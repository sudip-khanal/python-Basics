# %% [markdown]
# <a href="https://colab.research.google.com/github/sudip-khanal/python-Basics/blob/main/insta_user_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_excel('/content/TestDataset-Instagram.xlsx')

# %%
dataset.head()
# Out:
#     Users  Number of Posts  Number of Followers  Number of Followings  \
# 0  User-1              633                  566                   500
# 1  User-2              150                  434                   283
# 2  User-3              145                 1186                   651
# 3  User-4              477                  424                   324
# 4  User-5             1313                  939                   194
#
#    Number of Likes for the Tenth Previous Post  \
# 0                                           61
# 1                                           65
# 2                                           89
# 3                                           88
# 4                                           67
#
#    Number of Likes for the Eleventh Previous Post  \
# 0                                              61
# 1                                              64
# 2                                              88
# 3                                              76
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Users                                                     100 non-null    object
#  1   Number of Posts                                           100 non-null    int64
#  2   Number of Followers                                       100 non-null    int64
#  3   Number of Followings                                      100 non-null    int64
#  4   Number of Likes for the Tenth Previous Post               100 non-null    int64
#  5   Number of Likes for the Eleventh Previous Post            100 non-null    int64
#  6   Number of Likes for the Twelfth Previous Post             100 non-null    int64
#  7   Number of Self-Presenting Posts from Nine Previous Posts  100 non-null    int64
# ...

# %%
dataset.isnull().sum()
# Out:
# Users                                                       0
# Number of Posts                                             0
# Number of Followers                                         0
# Number of Followings                                        0
# Number of Likes for the Tenth Previous Post                 0
# Number of Likes for the Eleventh Previous Post              0
# Number of Likes for the Twelfth Previous Post               0
# Number of Self-Presenting Posts from Nine Previous Posts    0
#  Gender                                                     0
# dtype: int64

# %%
sns.countplot(x='Number of Posts',data=dataset)
plt.show()
